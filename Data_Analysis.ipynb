# %% [markdown]
# <a href="https://colab.research.google.com/github/anchalsinha-0411/Data-Analysis/blob/main/Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/drive/MyDrive/Untitled folder/brics.csv")

# %%
df
# Out:
#   Unnamed: 0       country  population      area    capital
# 0         BR        Brazil         200   8515767   Brasilia
# 1         RU        Russia         144  17098242     Moscow
# 2         IN         India        1252   3287590  New Delhi
# 3         CH         China        1357   9596961    Beijing
# 4         SA  South Africa          55   1221037   Pretoria

# %%
df.head()
# Out:
#   Unnamed: 0       country  population      area    capital
# 0         BR        Brazil         200   8515767   Brasilia
# 1         RU        Russia         144  17098242     Moscow
# 2         IN         India        1252   3287590  New Delhi
# 3         CH         China        1357   9596961    Beijing
# 4         SA  South Africa          55   1221037   Pretoria

# %%
df.tail()
# Out:
#   Unnamed: 0       country  population      area    capital
# 0         BR        Brazil         200   8515767   Brasilia
# 1         RU        Russia         144  17098242     Moscow
# 2         IN         India        1252   3287590  New Delhi
# 3         CH         China        1357   9596961    Beijing
# 4         SA  South Africa          55   1221037   Pretoria

# %%
df.describe()
# Out:
#         population          area
# count     5.000000  5.000000e+00
# mean    601.600000  7.943919e+06
# std     644.806405  6.199591e+06
# min      55.000000  1.221037e+06
# 25%     144.000000  3.287590e+06
# 50%     200.000000  8.515767e+06
# 75%    1252.000000  9.596961e+06
# max    1357.000000  1.709824e+07

# %%
df.dtypes
# Out:
# Unnamed: 0    object
# country       object
# population     int64
# area           int64
# capital       object
# dtype: object

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'population'}>,
#         <Axes: title={'center': 'area'}>]], dtype=object)

# %%
df.isnull()
# Out:
#    Unnamed: 0  country  population   area  capital
# 0       False    False       False  False    False
# 1       False    False       False  False    False
# 2       False    False       False  False    False
# 3       False    False       False  False    False
# 4       False    False       False  False    False

# %%
df.value_counts()
# Out:
# Unnamed: 0  country       population  area      capital
# BR          Brazil        200         8515767   Brasilia     1
# CH          China         1357        9596961   Beijing      1
# IN          India         1252        3287590   New Delhi    1
# RU          Russia        144         17098242  Moscow       1
# SA          South Africa  55          1221037   Pretoria     1
# Name: count, dtype: int64

# %%
df1=pd.read_csv('/content/drive/MyDrive/Untitled folder/brics.csv',index_col=0)

# %%
df1
# Out:
#          country  population      area    capital
# BR        Brazil         200   8515767   Brasilia
# RU        Russia         144  17098242     Moscow
# IN         India        1252   3287590  New Delhi
# CH         China        1357   9596961    Beijing
# SA  South Africa          55   1221037   Pretoria

# %%
df['country']
# Out:
# BR          Brazil
# RU          Russia
# IN           India
# CH           China
# SA    South Africa
# Name: country, dtype: object

# %%
df.country
# Out:
# BR          Brazil
# RU          Russia
# IN           India
# CH           China
# SA    South Africa
# Name: country, dtype: object

# %%
df
# Out:
#          country  population      area    capital
# BR        Brazil         200   8515767   Brasilia
# RU        Russia         144  17098242     Moscow
# IN         India        1252   3287590  New Delhi
# CH         China        1357   9596961    Beijing
# SA  South Africa          55   1221037   Pretoria

# %%
df['density'] = df['population'] / df['area'] * 1000000

# %%
df
# Out:
#          country  population      area    capital     density
# BR        Brazil         200   8515767   Brasilia   23.485847
# RU        Russia         144  17098242     Moscow    8.421918
# IN         India        1252   3287590  New Delhi  380.826076
# CH         China        1357   9596961    Beijing  141.398928
# SA  South Africa          55   1221037   Pretoria   45.043680

# %%
s=pd.Series(df['density'],dtype='int32')
pd.to_numeric(s)
# Out:
# BR     23
# RU      8
# IN    380
# CH    141
# SA     45
# Name: density, dtype: int32

# %%
df.loc["BR"]
# Out:
# country          Brazil
# population          200
# area            8515767
# capital        Brasilia
# density       23.485847
# Name: BR, dtype: object

# %%
df.iloc[1:3]
# Out:
#    country  population      area    capital     density
# RU  Russia         144  17098242     Moscow    8.421918
# IN   India        1252   3287590  New Delhi  380.826076

# %%
df.iloc[1:3,2:4]
# Out:
#         area    capital
# RU  17098242     Moscow
# IN   3287590  New Delhi

# %%
country_name=df[df['population']> 350]['country']
for country in country_name:
    print(country)
# Out:
# India
# China

# %%
#name of the top three country based on population

# %%
top3_countries = df.sort_values(by='population', ascending=False).head(3)['country']
for country in top3_countries:
    print(country)
# Out:
# China
# India
# Brazil

# %%
import pandas as pd

# %%
df1=pd.read_csv('/content/drive/MyDrive/Untitled folder/census.csv')

# %%
df1
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME            CTYNAME  \
# 0         50       3         6      1       1  Alabama     Autauga County
# 1         50       3         6      1       3  Alabama     Baldwin County
# 2         50       3         6      1       5  Alabama     Barbour County
# 3         50       3         6      1       7  Alabama        Bibb County
# 4         50       3         6      1       9  Alabama      Blount County
# ...      ...     ...       ...    ...     ...      ...                ...
# 3137      50       4         8     56      37  Wyoming  Sweetwater County
# 3138      50       4         8     56      39  Wyoming       Teton County
# 3139      50       4         8     56      41  Wyoming       Uinta County
# 3140      50       4         8     56      43  Wyoming    Washakie County
# 3141      50       4         8     56      45  Wyoming      Weston County
#
#       CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  \
# ...

# %%
df1.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      50       3         6      1       1  Alabama  Autauga County
# 1      50       3         6      1       3  Alabama  Baldwin County
# 2      50       3         6      1       5  Alabama  Barbour County
# 3      50       3         6      1       7  Alabama     Bibb County
# 4      50       3         6      1       9  Alabama   Blount County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 0          54571              54571            54660  ...          7.242091
# 1         182265             182265           183193  ...         14.832960
# 2          27457              27457            27341  ...         -4.728132
# 3          22915              22919            22861  ...         -5.527043
# 4          57322              57322            57373  ...          1.807375
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# ...

# %%
df1.tail()
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME            CTYNAME  \
# 3137      50       4         8     56      37  Wyoming  Sweetwater County
# 3138      50       4         8     56      39  Wyoming       Teton County
# 3139      50       4         8     56      41  Wyoming       Uinta County
# 3140      50       4         8     56      43  Wyoming    Washakie County
# 3141      50       4         8     56      45  Wyoming      Weston County
#
#       CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  \
# 3137          43806              43806            43593  ...
# 3138          21294              21294            21297  ...
# 3139          21118              21118            21102  ...
# 3140           8533               8533             8545  ...
# 3141           7208               7208             7181  ...
#
#       RDOMESTICMIG2011  RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  \
# ...

# %%
df1.describe()
# Out:
#        SUMLEV       REGION     DIVISION        STATE       COUNTY  \
# count  3142.0  3142.000000  3142.000000  3142.000000  3142.000000
# mean     50.0     2.668682     5.192553    30.280076   103.572884
# std       0.0     0.803149     1.964060    15.144339   107.704060
# min      50.0     1.000000     1.000000     1.000000     1.000000
# 25%      50.0     2.000000     4.000000    18.000000    35.000000
# 50%      50.0     3.000000     5.000000    29.000000    79.000000
# 75%      50.0     3.000000     7.000000    45.000000   133.000000
# max      50.0     4.000000     9.000000    56.000000   840.000000
#
#        CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  POPESTIMATE2011  \
# count   3.142000e+03       3.142000e+03     3.142000e+03     3.142000e+03
# mean    9.826204e+04       9.826802e+04     9.845540e+04     9.921033e+04
# std     3.129467e+05       3.129583e+05     3.135478e+05     3.167040e+05
# min     8.200000e+01       8.200000e+01     8.300000e+01     9.000000e+01
# ...

# %%
df1.dtypes
# Out:
# SUMLEV           int64
# REGION           int64
# DIVISION         int64
# STATE            int64
# COUNTY           int64
#                 ...
# RNETMIG2011    float64
# RNETMIG2012    float64
# RNETMIG2013    float64
# RNETMIG2014    float64
# RNETMIG2015    float64
# Length: 100, dtype: object

# %%
s=df1['STNAME'].value_counts()
p=s.idxmax()

# %%
p
# Out:
# 'Texas'

# %%
#only looking at the three most populous counties for each state,what are the three most populous states(in order of highest population to lowest population)?
sorted_counties= counties_df.sort_values(by=['STNAME', 'POPESTIMATE2010'], ascending=[True,False])
t= sorted_counties.groupby('STNAME').head(3)

# %%
sum = t.groupby('STNAME')['POPESTIMATE2010'].sum()

# %%
top_states =sum.sort_values(ascending=False).head(3)

# %%
for state in top_states.index.tolist():
    print(state)
# Out:
# California
# Texas
# Illinois

# %%
#print the all the state name who's birth rate lies between 14000-15000(using column birth2010)

# %%
s= df1[(df1['BIRTHS2010'] > 14000) & (df1['BIRTHS2010'] < 16000)]['STNAME'].unique()

# %%
for state in s:
  print(state)

# %%
state
# Out:
# 'Illinois'

# %%
x=df1.groupby('STNAME').sum()['BIRTHS2010']
ans=x[(x>14000) & (x<16000)]
print(ans)
# Out:
# STNAME
# Alabama           14226
# Louisiana         14573
# South Carolina    14180
# Name: BIRTHS2010, dtype: int64
